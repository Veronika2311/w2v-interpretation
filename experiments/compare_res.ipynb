# %%
import pickle
#with open('./models_res/180/180_res_three_parts_with_center.pkl', 'rb') as f:
with open('./models_res/180/180_res_sigma_half.pkl', 'rb') as f:
    res_180 = pickle.load(f)

# %%
with open('./models_res/180/180_res_three_parts_with_center.pkl', 'rb') as f:
    res_180_three = pickle.load(f)

# %%
with open('./models_res/araneum/araneum_res_sigma_half.pkl', 'rb') as f:
#with open('./models_res/araneum/araneum_res_three_parts_with_center.pkl', 'rb') as f:
    res_araneum = pickle.load(f)

# %%
res_180['1'][0][:500]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22240/26477300.py in <module>
# ----> 1 res_180['1'][0][:500]
#
# NameError: name 'res_180' is not defined

# %%
import seaborn as sns

sns_plot = sns.barplot([len(i) for i in res_180['2']])
fig = sns_plot.get_figure()
# Out:
# C:\Users\veron\Anaconda3\envs\main\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
plt.bar(np.arange(len(res_180['2'])), [len(i) for i in res_180['2']])
# Out:
# <BarContainer object of 9 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

ax.hist([len(i) for i in res_180['2']])
ax.grid()
 
plt.show()

# %%
import matplotlib.pyplot as plt

plt.histplot([len(i) for i in res_180['2']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29856/2232365363.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.histplot([len(i) for i in res_180['2']])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histplot'

# %%
[len(i) for i in res_180['2']]
# Out:
# [2146, 2819, 2380, 4379, 16164, 6737, 2246, 3914, 2161]

# %%
len(res_180['5'])
# Out:
# 243

# %%
len(set(res_180['1'][0]) & set(res_araneum['1'][0]))
# Out:
# 4190

# %%
len(set(res_180['1'][1]) & set(res_araneum['1'][1]))
# Out:
# 5975

# %%
len(set(res_180['1'][0]) & set(res_araneum['1'][1]))
# Out:
# 2585

# %%
len(set(res_180['1'][1]) & set(res_araneum['1'][0]))
# Out:
# 3937

# %%
len(set(res_180['1'][0]) & set(res_180_three['1'][0]))
# Out:
# 3962

# %%
len(set(res_180['1'][0]) & (set(res_180_three['1'][1])))
# Out:
# 4361

# %%
from nltk.draw import dispersion_plot

dispersion_plot(res_180['1'][0], list(set(res_180['1'][0]) & set(res_araneum['1'][0])))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3680/26562246.py in <module>
#       1 from nltk.draw import dispersion_plot
#       2
# ----> 3 dispersion_plot(res_180['1'][0], list(set(res_180['1'][0]) & set(res_araneum['1'][0])))
#
# ~\Anaconda3\envs\main\lib\site-packages\nltk\draw\dispersion.py in dispersion_plot(text, words, ignore_case, title)
#      56     pylab.title(title)
#      57     pylab.xlabel("Word Offset")
# ---> 58     pylab.show()
#      59
#      60
#
# ~\Anaconda3\envs\main\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# ~\Anaconda3\envs\main\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
tech_var_180 = []
for i in res_180['1'][0]:
    if i in set(res_180['1'][0]) & set(res_araneum['1'][0]):
        tech_var_180.append(1)
    else:
        tech_var_180.append(0)

# %%
tech_var_araneum = []
for i in res_araneum['1'][0]:
    if i in set(res_180['1'][0]) & set(res_araneum['1'][0]):
        tech_var_araneum.append(1)
    else:
        tech_var_araneum.append(0)

# %%
import seaborn as sns
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt

plt.figure(figsize=(15,8))
sns.heatmap(pd.DataFrame(tech_var_180))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(pd.DataFrame(tech_var_araneum))
# Out:
# <AxesSubplot:>
