# %%
import re
import os
from tqdm import tqdm
import sys
import gensim, logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
path_to_preproc = 'C:\\Users\\veron\\notebooks\\LSA\\to_w2v\\preproc'

# %%
data = gensim.models.word2vec.PathLineSentences(path_to_preproc)
# Out:
# 2022-03-09 18:11:45,686 : INFO : reading directory C:\Users\veron\notebooks\LSA\to_w2v\preproc\
# 2022-03-09 18:11:45,691 : INFO : files read into PathLineSentences:C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1038711.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1126057.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1212077.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1298079.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1384885.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1471851.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1558333.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1645227.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_171631.txt
# C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1731799.txt
# ...

# %%
wmodel = gensim.models.Word2Vec(data, vector_size=300, window=10, min_count=4, sg=0)
# Out:
# 2022-03-04 05:12:01,095 : INFO : collecting all words and their counts
# 2022-03-04 05:12:01,103 : INFO : reading file C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1038711.txt
# 2022-03-04 05:12:01,109 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-04 05:12:01,349 : INFO : PROGRESS: at sentence #10000, processed 147814 words, keeping 17890 word types
# 2022-03-04 05:12:01,590 : INFO : PROGRESS: at sentence #20000, processed 293148 words, keeping 29321 word types
# 2022-03-04 05:12:01,842 : INFO : PROGRESS: at sentence #30000, processed 437005 words, keeping 42595 word types
# 2022-03-04 05:12:02,060 : INFO : reading file C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1126057.txt
# 2022-03-04 05:12:02,108 : INFO : PROGRESS: at sentence #40000, processed 602264 words, keeping 53098 word types
# 2022-03-04 05:12:02,362 : INFO : PROGRESS: at sentence #50000, processed 763775 words, keeping 63557 word types
# ...

# %%
wmodel.train(data, total_examples=wmodel.corpus_count, epochs=30, report_delay=300)
# Out:
# 2022-03-04 08:37:59,667 : WARNING : Effective 'alpha' higher than previous training cycles
# 2022-03-04 08:37:59,668 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 1540086 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2022-03-04T08:37:59.668751', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'train'}
# 2022-03-04 08:37:59,671 : INFO : reading file C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1038711.txt
# 2022-03-04 08:38:00,376 : INFO : reading file C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1126057.txt
# 2022-03-04 08:38:00,677 : INFO : EPOCH 1 - PROGRESS: at 0.28% examples, 695719 words/s, in_qsize 5, out_qsize 0
# 2022-03-04 08:38:01,121 : INFO : reading file C:\Users\veron\notebooks\LSA\to_w2v\preproc\all_cyberleninka_archi_1212077.txt
# ...

# %%
model.wv.vocab

# %%
wmodel.save('test2.model')
# Out:
# 2022-03-04 12:20:30,721 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'test2.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-03-04T12:20:30.721446', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19043-SP0', 'event': 'saving'}
# 2022-03-04 12:20:30,724 : INFO : storing np array 'vectors' to test2.model.wv.vectors.npy
# 2022-03-04 12:21:20,724 : INFO : storing np array 'syn1neg' to test2.model.syn1neg.npy
# 2022-03-04 12:21:31,979 : INFO : not storing attribute cum_table
# 2022-03-04 12:21:50,583 : INFO : saved test2.model
